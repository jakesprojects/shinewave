# %%
# !flask run -p 3000
# Out:
#  * Serving Flask app 'run.py' (lazy loading)
#  * Environment: development
#  * Debug mode: on
# [2023-03-04 06:23:27,885] INFO in run: DEBUG            = True
# [2023-03-04 06:23:27,886] INFO in run: FLASK_ENV        = development
# [2023-03-04 06:23:27,886] INFO in run: Page Compression = FALSE
# [2023-03-04 06:23:27,886] INFO in run: DBMS             = sqlite:////srv/frontend/apps/db.sqlite3
# [2023-03-04 06:23:27,886] INFO in run: ASSETS_ROOT      = /static/assets
#  * Running on http://127.0.0.1:3000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 724-712-003
# [2023-03-04 06:23:29,880] INFO in run: DEBUG            = True
# [2023-03-04 06:23:29,881] INFO in run: FLASK_ENV        = development
# [2023-03-04 06:23:29,881] INFO in run: Page Compression = FALSE
# [2023-03-04 06:23:29,881] INFO in run: DBMS             = sqlite:////srv/frontend/apps/db.sqlite3
# [2023-03-04 06:23:29,881] INFO in run: ASSETS_ROOT      = /static/assets
# ...

# %%
# !pip freeze

# %%
# !killall -u myuser

# %%
# !cat /run/user/1000/xpra/:80.log

# %%
# !cd /srv/node_app && su root -c 'python3 app_launcher.py'

# %%
import subprocess
import re

ifconfig = subprocess.check_output('ifconfig eth0', shell=True).decode()
print(ifconfig)

# %%
re.findall(r'\W(inet [0-9]{3}\.[0-9]{2}(?:\.[0-9]{3}){2})\W', ifconfig)
