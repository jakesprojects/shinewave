# %%
# !xclock

# %%
# !python3 run_examples.py
# Out:
# Qt.py [warning]: ImportError(QtMultimedia): libpulse-mainloop-glib.so.0: cannot open shared object file: No such file or directory
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
# Traceback (most recent call last):
#   File "/srv/examples/hotkeys/hotkey_functions.py", line 76, in save_session
#     _save_session_as(graph)
# NameError: name '_save_session_as' is not defined
# ^C

# %%
# !chmod 777 ../* -R
