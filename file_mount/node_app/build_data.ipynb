# %%
"""
SMS Template Magic

first_name
last_name
key_date
key_time
response_phone_number
today (+/-)
custom_fields (json key)
"""

sample_templates = """
"Don't forget about your healthcare appointment today at [time]. Please arrive 10 minutes early and bring along your ID and insurance card. If you need to reschedule, please call [office phone number]. We look forward to seeing you soon!"
"""

# %%
import subprocess

from jakenode.database_connector import build_dummy_data

build_dummy_data()
subprocess.run('chmod 777 ./data/test_db.db', shell=True)
# Out:
# DROP TABLE IF EXISTS workflow_routes;
# CREATE TABLE workflow_routes (
#     id INTEGER,
#     account_id INTEGER,
#     workflow_id INTEGER,
#     app_server_address TEXT,
#     xpra_port INTEGER,
#     info_panel_port INTEGER,
#     websocket INTEGER,
#     x11_display INTEGER,
#     active TEXT,
#     last_activity TEXT
# );
# INSERT INTO workflow_routes VALUES
# ('1', '1', '1', 'localhost', '', '49153', '49152', '80', 'FALSE', '2023-02-16 21:46:30.353091'),
# ('2', '1', '2', 'localhost', '49154', '49155', '49154', '0', 'FALSE', '2023-02-16 21:46:30.353091'),
# ('3', '1', '3', 'localhost', '', '50000', '', '', '', '')
# ;
# DROP TABLE IF EXISTS templates;
# CREATE TABLE templates (
#     id INTEGER,
#     account_id INTEGER,
#     name TEXT,
#     template_type TEXT,
#     workflow_category_id INTEGER,
#     active TEXT
# );
# INSERT INTO templates VALUES
# ('1', '1', 'Same Day Appt Reminder', 'nodes.outreach.SMSOutreach', '1', 'TRUE'),
# ('2', '1', 'Prescription Reminder', 'nodes.outreach.SMSOutreach', '2', 'TRUE'),
# ('3', '2', 'Same Day Appt Reminder', 'nodes.outreach.SMSOutreach', '4', 'TRUE'),
# ('4', '2', 'Prescription Reminder', 'nodes.outreach.SMSOutreach', '3', 'TRUE')
# ;
# DROP TABLE IF EXISTS workflows;
# CREATE TABLE workflows (
#     id INTEGER,
#     account_id INTEGER,
#     name TEXT,
#     workflow_category_id INTEGER,
#     active TEXT
# );
# INSERT INTO workflows VALUES
# ('1', '1', 'Test APPT Reminder', '1', 'TRUE'),
# ('2', '1', 'Test Presc Reminder', '2', 'TRUE'),
# ('3', '2', 'Test Presc Reminder', '3', 'TRUE')
# ;
# DROP TABLE IF EXISTS members;
# CREATE TABLE members (
#     id INTEGER,
#     account_id INTEGER,
#     provider_id TEXT,
#     first_name TEXT,
#     last_name TEXT,
#     phone_number INTEGER,
#     email TEXT,
#     key_date TEXT,
#     key_time TEXT,
#     custom_data TEXT,
#     active TEXT
# );
# INSERT INTO members VALUES
# ('1', '1', 'm394y78sdh7', 'Joe', 'Johnson', '1234567890', 'Joe.Johnson@gmail.com', '2/17/2023', '12:21:22:00', '{"prescription_1": "Testagra", "prescription_2": "Molisia"}', 'TRUE'),
# ('2', '1', 'rns9frh9747', 'Pam', 'Morrison', '2561321325', 'Pam.Morrison@gmail.com', '4/23/2023', '02:38:27:00', '{"prescription_1": "Molisia"}', 'TRUE'),
# ('3', '2', 'dsf9r8hjf98we4utgyh', 'Mike', 'Brown', '8456917435', 'Mike.Brown@gmail.com', '3/1/2023', '03:46:08:00', '{"prescription_1": "Testagra", "prescription_2": "Molisia"}', 'TRUE'),
# ('4', '2', 'msg9wj8rfw98fhj', 'Rico', 'Gonzales', '1658453652', 'Rico.Gonzales@gmail.com', '4/7/2023', '23:17:17:00', '{"prescription_1": "Molisia", "prescription_2": "Testagra"}', 'TRUE')
# ;
# DROP TABLE IF EXISTS workflow_categories;
# CREATE TABLE workflow_categories (
#     id INTEGER,
#     account_id INTEGER,
#     name TEXT,
#     active TEXT
# );
# INSERT INTO workflow_categories VALUES
# ('1', '1', 'Appointment Reminders', 'TRUE'),
# ('2', '1', 'Prescription Reminders', 'TRUE'),
# ('3', '2', 'Prescription Reminders', 'TRUE'),
# ('4', '2', 'Appointment Reminders', 'TRUE'),
# ('5', '1', 'Lab Test Results Notifications', 'TRUE')
# ;
# DROP TABLE IF EXISTS account;
# CREATE TABLE account (
#     id INTEGER,
#     name TEXT,
#     contact_phone_number INTEGER,
#     contact_email TEXT,
#     active TEXT
# );
# INSERT INTO account VALUES
# ('1', 'Crazy Jakes Insurance Barn', '3521486954', 'jake@crazyjakes.com', 'TRUE'),
# ('2', 'Drugs r Us', '5248756548', 'script@gethooked.com', 'TRUE')
# ;
# DROP TABLE IF EXISTS outreach_lists;
# CREATE TABLE outreach_lists (
#     id INTEGER,
#     account_id INTEGER,
#     workflow_id INTEGER,
#     source_event_id INTEGER,
#     member_id INTEGER,
#     previous_state_id INTEGER,
#     previous_state_time TEXT,
#     pending_triggers TEXT,
#     active TEXT
# );
# CompletedProcess(args='chmod 777 ./data/test_db.db', returncode=0)

# %%
# !chmod 777 ./data/test_db.db
