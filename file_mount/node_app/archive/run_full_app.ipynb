# %%
from multiprocessing import Process, Queue
import subprocess

from run_info_pane import run_info_pane
from run_node_app import run_node_app

def run_xpra_window(queue):
    script_target = 'run_two_window_app.py'
    x11_screen = 80
    xpra_target_port = '8080'
    user = 'myuser'
    
    current_working_directory = subprocess.check_output('pwd')
    current_working_directory = current_working_directory.decode().strip()
    script_filepath = f'{current_working_directory}/{script_target}'

    base_command = f'xpra start :{x11_screen}'
    flags = [
        f'--bind-tcp=0.0.0.0:{xpra_target_port}',
        '--mdns=no',
        '--webcam=no',
        '--no-daemon',
        '--pulseaudio=no',
        f'--start="python3 {script_filepath}"'
    ]
    
    flags = ' '.join(flags)
     
    command = f"su myuser -c '{base_command} {flags}'"
    print(command)
    subprocess.call(command, shell=True)

# %%
run_xpra_window(None)
# !su myuser -c 'xpra start :80 --bind-tcp=0.0.0.0:8080 --mdns=no --webcam=no --no-daemon --pulseaudio=no --start="python3 /srv/node_app/run_two_window_app.py"'
# Out:
# su myuser -c 'xpra start :80 --bind-tcp=0.0.0.0:8080 --mdns=no --webcam=no --no-daemon --pulseaudio=no --start="python3 /srv/node_app/run_two_window_app.py"'
# 2023-02-07 03:32:36,642 Warning: failed to create script directory '/run/user/1000/xpra':
# 2023-02-07 03:32:36,642  [Errno 2] No such file or directory: '/run/user/1000/xpra'
# 2023-02-07 03:32:36,642  ($XDG_RUNTIME_DIR has not been created?)
# 2023-02-07 03:32:36,768 created tcp socket '0.0.0.0:8080'
# 2023-02-07 03:32:36,775 cannot access python uinput module:
# 2023-02-07 03:32:36,776  No module named 'uinput'
# _XSERVTransmkdir: Mode of /tmp/.X11-unix should be set to 1777
# _XSERVTransSocketCreateListener: failed to bind listener
# _XSERVTransSocketUNIXCreateListener: ...SocketCreateListener() failed
# _XSERVTransMakeAllCOTSServerListeners: failed to create listener for unix
# 2023-02-07 03:32:36,802 dbus-launch failed to start using command 'dbus-launch --sh-syntax --close-stderr':
#
# 2023-02-07 03:32:36,802  exit code is 255
#
# 2023-02-07 03:32:37,133 Warning: failed to create socket directory '/run/user/1000/xpra'
# 2023-02-07 03:32:37,133  [Errno 2] No such file or directory: '/run/user/1000/xpra'
# 2023-02-07 03:32:37,133 Warning: failed to create socket directory '/run/xpra'
# 2023-02-07 03:32:37,133  [Errno 13] Permission denied: '/run/xpra'
# 2023-02-07 03:32:37,134 Warning: cannot create socket '/run/user/1000/xpra/DESKTOP-40SJTT3-80':
# 2023-02-07 03:32:37,134  [Errno 2] No such file or directory
# 2023-02-07 03:32:37,134  /run/user does not exist
# 2023-02-07 03:32:37,134 cannot create group socket '/run/xpra/DESKTOP-40SJTT3-80'
# 2023-02-07 03:32:37,134  [Errno 2] No such file or directory
# 2023-02-07 03:32:37,135  /run/xpra does not exist
# 2023-02-07 03:32:37,136 created unix domain socket '/home/myuser/.xpra/DESKTOP-40SJTT3-80'
# 2023-02-07 03:32:37,213 pointer device emulation using XTest
# 2023-02-07 03:32:37,282 serving html content from '/usr/share/xpra/www'
# 2023-02-07 03:32:38,461 OpenGL is supported on display ':80'
# 2023-02-07 03:32:38,461  using 'llvmpipe (LLVM 11.0.1, 256 bits)' renderer
# 2023-02-07 03:32:38,518 dbus server error
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_common.py", line 12, in dbus_exception_wrap
#     v = fn()
#   File "/usr/lib/python3/dist-packages/xpra/x11/server.py", line 1393, in make_dbus_server
#     return X11_DBUS_Server(self, os.environ.get("DISPLAY", "").lstrip(":"))
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_server.py", line 42, in __init__
#     bus = init_session_bus()
#   File "/usr/lib/python3/dist-packages/xpra/dbus/common.py", line 22, in init_session_bus
#     _session_bus = dbus.SessionBus(private=private)
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 212, in __new__
#     return Bus.__new__(cls, Bus.TYPE_SESSION, private=private,
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 102, in __new__
#     bus = BusConnection.__new__(subclass, bus_type, mainloop=mainloop)
#   File "/usr/lib/python3/dist-packages/dbus/bus.py", line 124, in __new__
#     bus = cls._new_for_bus(address_or_type, mainloop=mainloop)
# dbus.exceptions.DBusException: org.freedesktop.DBus.Error.Spawn.ExecFailed: /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 03:32:38,519 Error setting up server dbus instance:
# 2023-02-07 03:32:38,520   org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 03:32:38,522   /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 03:32:38,531 Warning: cannot forward notifications,
# 2023-02-07 03:32:38,532  failed to load or register our dbus notifications forwarder:
# 2023-02-07 03:32:38,532  org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 03:32:38,532  /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 03:32:38,532  if you do not have a dedicated dbus session for this xpra instance,
# 2023-02-07 03:32:38,533  use the 'notifications=no' option
# 2023-02-07 03:32:38,557 Warning: cannot load dbus helper:
# 2023-02-07 03:32:38,557  org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 03:32:38,557  /usr/bin/dbus-launch terminated abnormally without any error message
#
# (Xpra:343): Gtk-CRITICAL **: 03:32:38.558: gtk_widget_realize: assertion 'widget->priv->anchored || GTK_IS_INVISIBLE (widget)' failed
# 2023-02-07 03:32:38,600 Error: lpinfo command failed to run
# 2023-02-07 03:32:38,600  [Errno 2] No such file or directory: '/usr/sbin/lpinfo'
# 2023-02-07 03:32:38,601  command used: '/usr/sbin/lpinfo --make-and-model Generic PDF Printer -m'
# 2023-02-07 03:32:38,603 printer forwarding enabled using postscript
# 2023-02-07 03:32:38,618 Warning: cannot watch for application menu changes without pyinotify:
# 2023-02-07 03:32:38,618  No module named 'pyinotify'
# 2023-02-07 03:32:38,652 Error parsing xdg menu data:
# 2023-02-07 03:32:38,653  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 03:32:38,655  this is either a bug in python-xdg,
# 2023-02-07 03:32:38,655  or an invalid system menu configuration
# 2023-02-07 03:32:38,837 xpra is ready.
# 2023-02-07 03:32:38,838 xpra GTK3 X11 version 3.0.13-r28292 64-bit
# 2023-02-07 03:32:38,944  uid=1000 (myuser), gid=1000 (myuser)
# 2023-02-07 03:32:38,944  running with pid 343 on Linux Debian 11 bullseye
# 2023-02-07 03:32:38,950  connected to X11 display :80 with 24 bit colors
# 2023-02-07 03:32:39,074 7.7GB of system memory
# WebSocket transport not available. Install simple-websocket for improved performance.
# Werkzeug appears to be used in a production deployment. Consider switching to a production web server instead.
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Serving Flask app 'run_two_window_app'
#  * Debug mode: off
# The WebSocket transport is not available, you must install a WebSocket server that is compatible with your async mode to enable it. See the documentation for details. (further occurrences of this error will be logged with level INFO)
# 127.0.0.1 - - [07/Feb/2023 03:32:42] "GET /socket.io/?EIO=4&transport=polling&t=OOfxj2I HTTP/1.1" 200 -
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-myuser'
# 127.0.0.1 - - [07/Feb/2023 03:32:42] "POST /socket.io/?EIO=4&transport=polling&t=OOfxj7R&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:42] "GET /socket.io/?EIO=4&transport=polling&t=OOfxj7R.0&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:42] "GET /socket.io/?EIO=4&transport=polling&t=OOfxj8R HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "POST /socket.io/?EIO=4&transport=polling&t=OOfxjD5&sid=d-RLtKw8QMw7xR0dAAAC HTTP/1.1" 200 -
# 2023-02-07 03:32:43,160 Error parsing xdg menu data:
# 2023-02-07 03:32:43,160  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 03:32:43,161  this is either a bug in python-xdg,
# 2023-02-07 03:32:43,161  or an invalid system menu configuration
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjD6&sid=d-RLtKw8QMw7xR0dAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "POST /socket.io/?EIO=4&transport=polling&t=OOfxjD8&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjD9&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "POST /socket.io/?EIO=4&transport=polling&t=OOfxjIP&sid=d-RLtKw8QMw7xR0dAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:43] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjIS&sid=d-RLtKw8QMw7xR0dAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:45] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjf7 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:45] "POST /socket.io/?EIO=4&transport=polling&t=OOfxjk7&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:45] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjk8&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 2023-02-07 03:32:45,494 Handshake complete; enabling connection
# 2023-02-07 03:32:45,522 dbus server error
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_common.py", line 12, in dbus_exception_wrap
#     v = fn()
#   File "/usr/lib/python3/dist-packages/xpra/server/source/dbus_mixin.py", line 29, in make_dbus_server
#     return DBUS_Source(self, os.environ.get("DISPLAY", "").lstrip(":"))
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_source.py", line 37, in __init__
#     session_bus = init_session_bus()
#   File "/usr/lib/python3/dist-packages/xpra/dbus/common.py", line 22, in init_session_bus
#     _session_bus = dbus.SessionBus(private=private)
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 212, in __new__
#     return Bus.__new__(cls, Bus.TYPE_SESSION, private=private,
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 102, in __new__
#     bus = BusConnection.__new__(subclass, bus_type, mainloop=mainloop)
#   File "/usr/lib/python3/dist-packages/dbus/bus.py", line 124, in __new__
#     bus = cls._new_for_bus(address_or_type, mainloop=mainloop)
# dbus.exceptions.DBusException: org.freedesktop.DBus.Error.Spawn.ExecFailed: /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 03:32:45,523 Error setting up client dbus instance:
# 2023-02-07 03:32:45,523   org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 03:32:45,523   /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 03:32:45,525  automatic picture encoding enabled, also available:
# 2023-02-07 03:32:45,525   jpeg, png, rgb32, webp, h264, mpeg1
# 2023-02-07 03:32:45,528 Warning: the python netifaces package is missing
# 2023-02-07 03:32:45,528 HTML5 Microsoft Windows Chrome client version 3.0.13
# 2023-02-07 03:32:45,536 setting keyboard layout to 'en'
# The XKEYBOARD keymap compiler (xkbcomp) reports:
# > Error:            Can't find file "en" for symbols include
# >                   Exiting
# >                   Abandoning symbols file "default"
# Errors from xkbcomp are not fatal to the X server
# 2023-02-07 03:32:45,555 Error loading new keyboard description
# 2023-02-07 03:32:45,604  client root window size is 1796x915 with 1 display:
# 2023-02-07 03:32:45,605   HTML (475x242 mm - DPI: 96x96)
# 2023-02-07 03:32:45,605     Canvas
# 127.0.0.1 - - [07/Feb/2023 03:32:45] "POST /socket.io/?EIO=4&transport=polling&t=OOfxjpA&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:45] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjpB&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 2023-02-07 03:32:46,112 server virtual display now set to 1796x915
# 2023-02-07 03:32:46,124 Error parsing xdg menu data:
# 2023-02-07 03:32:46,125  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 03:32:46,125  this is either a bug in python-xdg,
# 2023-02-07 03:32:46,125  or an invalid system menu configuration
# 2023-02-07 03:32:46,144 Warning: failed to add virtual printer 'HTML5 client'
# 2023-02-07 03:32:46,144  failed to connect to server
# 2023-02-07 03:32:46,144 client   1 received xdg start menu data
# 2023-02-07 03:32:46,175 client   1 startup complete
# 2023-02-07 03:32:46,193 client   1 connection-established
# 2023-02-07 03:32:46,205 DPI set to 96 x 96
# 2023-02-07 03:32:46,370 New tcp connection received
# 2023-02-07 03:32:46,370  from '127.0.0.1:59382'
# 2023-02-07 03:32:46,371  on '0.0.0.0:8080'
# 2023-02-07 03:32:46,374 Disconnecting client ('127.0.0.1', 59382):
# 2023-02-07 03:32:46,375  invalid packet format, HTTP GET request
# 2023-02-07 03:32:46,413 New tcp connection received
# 2023-02-07 03:32:46,413  from '127.0.0.1:59386'
# 2023-02-07 03:32:46,413  on '0.0.0.0:8080'
# 2023-02-07 03:32:46,418 Disconnecting client ('127.0.0.1', 59386):
# 2023-02-07 03:32:46,418  invalid packet format, HTTP GET request
# 2023-02-07 03:32:46,533 New tcp connection received
# 2023-02-07 03:32:46,533  from '127.0.0.1:59408'
# 2023-02-07 03:32:46,533  on '0.0.0.0:8080'
# 2023-02-07 03:32:47,242 New tcp connection received
# 2023-02-07 03:32:47,243  from '127.0.0.1:59424'
# 2023-02-07 03:32:47,243  on '0.0.0.0:8080'
# 2023-02-07 03:32:47,427 client   1 broadway decoder initialized
# 127.0.0.1 - - [07/Feb/2023 03:32:47] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjIP&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:47] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjNV&sid=d-RLtKw8QMw7xR0dAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:47] "GET /socket.io/?EIO=4&transport=polling&t=OOfxjuJ&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:47] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkMe&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:47] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkMg&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:48] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkRx&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:48] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkRo&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:48] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkZu&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 2023-02-07 03:32:48,594 client   1 broadway decoder initialized
# 127.0.0.1 - - [07/Feb/2023 03:32:48] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkZv&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:49] "GET /socket.io/?EIO=4&transport=polling&t=OOfxka8&sid=JgV4zWno4oBtqXgoAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 03:32:49] "GET /socket.io/?EIO=4&transport=polling&t=OOfxkey&sid=9BKG6Ad5uZhDF-eoAAAA HTTP/1.1" 200 -
# 2023-02-07 03:32:49,927 client   1 visibilitychange hidden= true connected= true

# %%
if __name__ == '__main__':
    queue = Queue()
    xpra_process = Process(target=run_node_app, args=(queue,))
    info_pane_process = Process(target=run_info_pane, args=(queue,))
    xpra_process.start()
    info_pane_process.start()
# Out:
# 2023-02-07 02:16:48.538230
# 0:00:00.010617
# WebSocket transport not available. Install simple-websocket for improved performance.
# Werkzeug appears to be used in a production deployment. Consider switching to a production web server instead.
#  * Serving Flask app 'run_info_pane'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
# The WebSocket transport is not available, you must install a WebSocket server that is compatible with your async mode to enable it. See the documentation for details. (further occurrences of this error will be logged with level INFO)
# 127.0.0.1 - - [07/Feb/2023 02:16:54] "GET /socket.io/?EIO=4&transport=polling&t=OOfgMal HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:16:54] "POST /socket.io/?EIO=4&transport=polling&t=OOfgMg1&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:16:54] "GET /socket.io/?EIO=4&transport=polling&t=OOfgMg3&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:16:54] "POST /socket.io/?EIO=4&transport=polling&t=OOfgMlD&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:16:54] "GET /socket.io/?EIO=4&transport=polling&t=OOfgMlE&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:17:19] "GET /socket.io/?EIO=4&transport=polling&t=OOfgMqQ&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:17:19] "POST /socket.io/?EIO=4&transport=polling&t=OOfgSm-&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:17:44] "GET /socket.io/?EIO=4&transport=polling&t=OOfgSm_&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:17:44] "POST /socket.io/?EIO=4&transport=polling&t=OOfgYu9&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:09] "GET /socket.io/?EIO=4&transport=polling&t=OOfgYuA&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:09] "POST /socket.io/?EIO=4&transport=polling&t=OOfgf4K&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:34] "GET /socket.io/?EIO=4&transport=polling&t=OOfgf4L&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:34] "POST /socket.io/?EIO=4&transport=polling&t=OOfglBY&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:59] "GET /socket.io/?EIO=4&transport=polling&t=OOfglBZ&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:18:59] "POST /socket.io/?EIO=4&transport=polling&t=OOfgrNq&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:19:24] "GET /socket.io/?EIO=4&transport=polling&t=OOfgrNr&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:19:25] "POST /socket.io/?EIO=4&transport=polling&t=OOfgxVC&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:19:50] "GET /socket.io/?EIO=4&transport=polling&t=OOfgxVE&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 02:19:50] "POST /socket.io/?EIO=4&transport=polling&t=OOfh1hI&sid=UGQHEADMZcmH3exWAAAA HTTP/1.1" 200 -
