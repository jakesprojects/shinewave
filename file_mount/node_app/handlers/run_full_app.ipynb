# %%
from multiprocessing import Process, Queue
import subprocess

def run_xpra_window(queue):
    script_target = 'run_two_window_app.py'
    x11_screen = 80
    xpra_target_port = '8080'
    user = 'myuser'
    
    current_working_directory = subprocess.check_output('pwd')
    current_working_directory = current_working_directory.decode().strip()
    script_filepath = f'{current_working_directory}/{script_target}'

    base_command = f'xpra start :{x11_screen}'
    flags = [
        f'--bind-tcp=0.0.0.0:{xpra_target_port}',
        '--mdns=no',
        '--webcam=no',
        '--no-daemon',
        '--pulseaudio=no',
        f'--start="python3 {script_filepath}"'
    ]
    
    flags = ' '.join(flags)
     
    command = f"su myuser -c '{base_command} {flags}'"
    print(command)
    subprocess.call(command, shell=True)

run_xpra_window(None)
# Out:
# su myuser -c 'xpra start :80 --bind-tcp=0.0.0.0:8080 --mdns=no --webcam=no --no-daemon --pulseaudio=no --start="python3 /srv/node_app/handlers/run_two_window_app.py"'
# 2023-02-07 06:39:22,907 Warning: failed to create script directory '/run/user/1000/xpra':
# 2023-02-07 06:39:22,907  [Errno 2] No such file or directory: '/run/user/1000/xpra'
# 2023-02-07 06:39:22,907  ($XDG_RUNTIME_DIR has not been created?)
# 2023-02-07 06:39:23,047 created tcp socket '0.0.0.0:8080'
# 2023-02-07 06:39:23,050 cannot access python uinput module:
# 2023-02-07 06:39:23,050  No module named 'uinput'
# _XSERVTransmkdir: Mode of /tmp/.X11-unix should be set to 1777
# _XSERVTransSocketCreateListener: failed to bind listener
# _XSERVTransSocketUNIXCreateListener: ...SocketCreateListener() failed
# _XSERVTransMakeAllCOTSServerListeners: failed to create listener for unix
# 2023-02-07 06:39:23,076 dbus-launch failed to start using command 'dbus-launch --sh-syntax --close-stderr':
#
# 2023-02-07 06:39:23,076  exit code is 255
#
# 2023-02-07 06:39:23,432 Warning: failed to create socket directory '/run/user/1000/xpra'
# 2023-02-07 06:39:23,432  [Errno 2] No such file or directory: '/run/user/1000/xpra'
# 2023-02-07 06:39:23,433 Warning: failed to create socket directory '/run/xpra'
# 2023-02-07 06:39:23,433  [Errno 13] Permission denied: '/run/xpra'
# 2023-02-07 06:39:23,434 Warning: cannot create socket '/run/user/1000/xpra/DESKTOP-40SJTT3-80':
# 2023-02-07 06:39:23,434  [Errno 2] No such file or directory
# 2023-02-07 06:39:23,434  /run/user does not exist
# 2023-02-07 06:39:23,437 cannot create group socket '/run/xpra/DESKTOP-40SJTT3-80'
# 2023-02-07 06:39:23,437  [Errno 2] No such file or directory
# 2023-02-07 06:39:23,437  /run/xpra does not exist
# 2023-02-07 06:39:23,438 created unix domain socket '/home/myuser/.xpra/DESKTOP-40SJTT3-80'
# 2023-02-07 06:39:23,524 pointer device emulation using XTest
# 2023-02-07 06:39:23,607 serving html content from '/usr/share/xpra/www'
# 2023-02-07 06:39:24,881 OpenGL is supported on display ':80'
# 2023-02-07 06:39:24,882  using 'llvmpipe (LLVM 11.0.1, 256 bits)' renderer
# 2023-02-07 06:39:24,938 dbus server error
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_common.py", line 12, in dbus_exception_wrap
#     v = fn()
#   File "/usr/lib/python3/dist-packages/xpra/x11/server.py", line 1393, in make_dbus_server
#     return X11_DBUS_Server(self, os.environ.get("DISPLAY", "").lstrip(":"))
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_server.py", line 42, in __init__
#     bus = init_session_bus()
#   File "/usr/lib/python3/dist-packages/xpra/dbus/common.py", line 22, in init_session_bus
#     _session_bus = dbus.SessionBus(private=private)
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 212, in __new__
#     return Bus.__new__(cls, Bus.TYPE_SESSION, private=private,
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 102, in __new__
#     bus = BusConnection.__new__(subclass, bus_type, mainloop=mainloop)
#   File "/usr/lib/python3/dist-packages/dbus/bus.py", line 124, in __new__
#     bus = cls._new_for_bus(address_or_type, mainloop=mainloop)
# dbus.exceptions.DBusException: org.freedesktop.DBus.Error.Spawn.ExecFailed: /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 06:39:24,940 Error setting up server dbus instance:
# 2023-02-07 06:39:24,940   org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 06:39:24,940   /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 06:39:24,949 Warning: cannot forward notifications,
# 2023-02-07 06:39:24,949  failed to load or register our dbus notifications forwarder:
# 2023-02-07 06:39:24,949  org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 06:39:24,949  /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 06:39:24,949  if you do not have a dedicated dbus session for this xpra instance,
# 2023-02-07 06:39:24,949  use the 'notifications=no' option
# 2023-02-07 06:39:24,965 Warning: cannot load dbus helper:
# 2023-02-07 06:39:24,965  org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 06:39:24,965  /usr/bin/dbus-launch terminated abnormally without any error message
#
# (Xpra:33): Gtk-CRITICAL **: 06:39:24.967: gtk_widget_realize: assertion 'widget->priv->anchored || GTK_IS_INVISIBLE (widget)' failed
# 2023-02-07 06:39:25,011 Error: lpinfo command failed to run
# 2023-02-07 06:39:25,012  [Errno 2] No such file or directory: '/usr/sbin/lpinfo'
# 2023-02-07 06:39:25,012  command used: '/usr/sbin/lpinfo --make-and-model Generic PDF Printer -m'
# 2023-02-07 06:39:25,013 printer forwarding enabled using postscript
# 2023-02-07 06:39:25,028 Warning: cannot watch for application menu changes without pyinotify:
# 2023-02-07 06:39:25,029  No module named 'pyinotify'
# 2023-02-07 06:39:25,073 Error parsing xdg menu data:
# 2023-02-07 06:39:25,073  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 06:39:25,073  this is either a bug in python-xdg,
# 2023-02-07 06:39:25,074  or an invalid system menu configuration
# 2023-02-07 06:39:25,281 xpra is ready.
# 2023-02-07 06:39:25,282 xpra GTK3 X11 version 3.0.13-r28292 64-bit
# 2023-02-07 06:39:25,391  uid=1000 (myuser), gid=1000 (myuser)
# 2023-02-07 06:39:25,393  running with pid 33 on Linux Debian 11 bullseye
# 2023-02-07 06:39:25,397  connected to X11 display :80 with 24 bit colors
# 2023-02-07 06:39:25,480 7.7GB of system memory
# WebSocket transport not available. Install simple-websocket for improved performance.
# Werkzeug appears to be used in a production deployment. Consider switching to a production web server instead.
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Serving Flask app 'run_two_window_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# The WebSocket transport is not available, you must install a WebSocket server that is compatible with your async mode to enable it. See the documentation for details. (further occurrences of this error will be logged with level INFO)
# 127.0.0.1 - - [07/Feb/2023 06:39:30] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTLR HTTP/1.1" 200 -
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-myuser'
# 127.0.0.1 - - [07/Feb/2023 06:39:30] "POST /socket.io/?EIO=4&transport=polling&t=OOgcTLa&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:30] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTLc&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:30] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTPQ HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:30] "POST /socket.io/?EIO=4&transport=polling&t=OOgcTXn&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 2023-02-07 06:39:31,103 Error parsing xdg menu data:
# 2023-02-07 06:39:31,104  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 06:39:31,104  this is either a bug in python-xdg,
# 2023-02-07 06:39:31,104  or an invalid system menu configuration
# 127.0.0.1 - - [07/Feb/2023 06:39:31] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTXo&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:31] "POST /socket.io/?EIO=4&transport=polling&t=OOgcTYB&sid=mXncGiD_XatO0h1XAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:31] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTYC&sid=mXncGiD_XatO0h1XAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:31] "POST /socket.io/?EIO=4&transport=polling&t=OOgcTdB&sid=mXncGiD_XatO0h1XAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:31] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTdC&sid=mXncGiD_XatO0h1XAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:33] "GET /socket.io/?EIO=4&transport=polling&t=OOgcUC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:34] "POST /socket.io/?EIO=4&transport=polling&t=OOgcUHC&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:34] "GET /socket.io/?EIO=4&transport=polling&t=OOgcUHD&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:34] "GET /socket.io/?EIO=4&transport=polling&t=OOgcUMS.0&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:34] "POST /socket.io/?EIO=4&transport=polling&t=OOgcUMS&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 2023-02-07 06:39:41,138 Handshake complete; enabling connection
# 2023-02-07 06:39:41,162 dbus server error
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_common.py", line 12, in dbus_exception_wrap
#     v = fn()
#   File "/usr/lib/python3/dist-packages/xpra/server/source/dbus_mixin.py", line 29, in make_dbus_server
#     return DBUS_Source(self, os.environ.get("DISPLAY", "").lstrip(":"))
#   File "/usr/lib/python3/dist-packages/xpra/server/dbus/dbus_source.py", line 37, in __init__
#     session_bus = init_session_bus()
#   File "/usr/lib/python3/dist-packages/xpra/dbus/common.py", line 22, in init_session_bus
#     _session_bus = dbus.SessionBus(private=private)
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 212, in __new__
#     return Bus.__new__(cls, Bus.TYPE_SESSION, private=private,
#   File "/usr/lib/python3/dist-packages/dbus/_dbus.py", line 102, in __new__
#     bus = BusConnection.__new__(subclass, bus_type, mainloop=mainloop)
#   File "/usr/lib/python3/dist-packages/dbus/bus.py", line 124, in __new__
#     bus = cls._new_for_bus(address_or_type, mainloop=mainloop)
# dbus.exceptions.DBusException: org.freedesktop.DBus.Error.Spawn.ExecFailed: /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 06:39:41,163 Error setting up client dbus instance:
# 2023-02-07 06:39:41,163   org.freedesktop.DBus.Error.Spawn.ExecFailed
# 2023-02-07 06:39:41,164   /usr/bin/dbus-launch terminated abnormally without any error message
# 2023-02-07 06:39:41,166  automatic picture encoding enabled, also available:
# 2023-02-07 06:39:41,166   jpeg, png, rgb32, webp, h264, mpeg1
# 2023-02-07 06:39:41,168 Warning: the python netifaces package is missing
# 2023-02-07 06:39:41,169 HTML5 Microsoft Windows Chrome client version 3.0.13
# 2023-02-07 06:39:41,177 setting keyboard layout to 'en'
# The XKEYBOARD keymap compiler (xkbcomp) reports:
# > Error:            Can't find file "en" for symbols include
# >                   Exiting
# >                   Abandoning symbols file "default"
# Errors from xkbcomp are not fatal to the X server
# 2023-02-07 06:39:41,203 Error loading new keyboard description
# 2023-02-07 06:39:41,232  client root window size is 1796x915 with 1 display:
# 2023-02-07 06:39:41,233   HTML (475x242 mm - DPI: 96x96)
# 2023-02-07 06:39:41,233     Canvas
# 2023-02-07 06:39:41,740 server virtual display now set to 1796x915
# 2023-02-07 06:39:41,752 Error parsing xdg menu data:
# 2023-02-07 06:39:41,753  ParsingError in file '/etc/xdg/menus/kde-debian-menu.menu', File not found
# 2023-02-07 06:39:41,753  this is either a bug in python-xdg,
# 2023-02-07 06:39:41,753  or an invalid system menu configuration
# 2023-02-07 06:39:41,773 Warning: failed to add virtual printer 'HTML5 client'
# 2023-02-07 06:39:41,774  failed to connect to server
# 2023-02-07 06:39:41,774 client   1 received xdg start menu data
# 2023-02-07 06:39:41,818 client   1 startup complete
# 2023-02-07 06:39:41,835 client   1 connection-established
# 2023-02-07 06:39:41,842 DPI set to 96 x 96
# 2023-02-07 06:39:42,876 New tcp connection received
# 2023-02-07 06:39:42,876  from '127.0.0.1:59648'
# 2023-02-07 06:39:42,876  on '0.0.0.0:8080'
# 2023-02-07 06:39:42,878 New tcp connection received
# 2023-02-07 06:39:42,878  from '127.0.0.1:59656'
# 2023-02-07 06:39:42,878  on '0.0.0.0:8080'
# 2023-02-07 06:39:44,486 client   1 broadway decoder initialized
# 2023-02-07 06:39:45,438 client   1 broadway decoder initialized
# 127.0.0.1 - - [07/Feb/2023 06:39:46] "GET /socket.io/?EIO=4&transport=polling&t=OOgcURb&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:46] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTiB&sid=mXncGiD_XatO0h1XAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:46] "GET /socket.io/?EIO=4&transport=polling&t=OOgcTcw&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:49] "GET /socket.io/?EIO=4&transport=polling&t=OOgcXDt&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:49] "GET /socket.io/?EIO=4&transport=polling&t=OOgcXDr&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 2023-02-07 06:39:49,873 client   1 broadway decoder initialized
# 127.0.0.1 - - [07/Feb/2023 06:39:51] "GET /socket.io/?EIO=4&transport=polling&t=OOgcX-1&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:51] "GET /socket.io/?EIO=4&transport=polling&t=OOgcXz_&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:55] "GET /socket.io/?EIO=4&transport=polling&t=OOgcYVm&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:55] "POST /socket.io/?EIO=4&transport=polling&t=OOgcZSd&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# 127.0.0.1 - - [07/Feb/2023 06:39:58] "GET /socket.io/?EIO=4&transport=polling&t=OOgcYVo&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:39:59] "POST /socket.io/?EIO=4&transport=polling&t=OOgcaOE&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:00] "GET /socket.io/?EIO=4&transport=polling&t=OOgcZSe&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:00] "GET /socket.io/?EIO=4&transport=polling&t=OOgcaOF&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:01] "GET /socket.io/?EIO=4&transport=polling&t=OOgcaf6&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:01] "GET /socket.io/?EIO=4&transport=polling&t=OOgcafB&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# 127.0.0.1 - - [07/Feb/2023 06:40:03] "GET /socket.io/?EIO=4&transport=polling&t=OOgcawE&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:03] "GET /socket.io/?EIO=4&transport=polling&t=OOgcawF&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 2023-02-07 06:40:03,878 Error: connection timed out: tcp socket: 127.0.0.1:8080 <- 127.0.0.1:59648
# 2023-02-07 06:40:03,880 Error: connection timed out: tcp socket: 127.0.0.1:8080 <- 127.0.0.1:59656
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# 127.0.0.1 - - [07/Feb/2023 06:40:05] "GET /socket.io/?EIO=4&transport=polling&t=OOgcbZN&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:05] "GET /socket.io/?EIO=4&transport=polling&t=OOgcbZN&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 2023-02-07 06:40:08,230 client   1 broadway decoder initialized
# 2023-02-07 06:40:08,956 client   1 broadway decoder initialized
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# 127.0.0.1 - - [07/Feb/2023 06:40:13] "GET /socket.io/?EIO=4&transport=polling&t=OOgcc3u&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:13] "GET /socket.io/?EIO=4&transport=polling&t=OOgcc3t&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 2023-02-07 06:40:13,789 client   1 broadway decoder initialized
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 27, in handle_node_selected
#     self.display_node_info(sub_node)
#   File "/usr/local/lib/python3.7/site-packages/jakenode/graph_handler.py", line 37, in display_node_info
#     title, description = node_handler.fetch_node_display_info(node)
# TypeError: cannot unpack non-iterable NoneType object
# 127.0.0.1 - - [07/Feb/2023 06:40:19] "GET /socket.io/?EIO=4&transport=polling&t=OOgcd_Z&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:19] "GET /socket.io/?EIO=4&transport=polling&t=OOgcd_b&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:19] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfMV&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:19] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfMX&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:20] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfVJ&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:20] "POST /socket.io/?EIO=4&transport=polling&t=OOgcfaR&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:21] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfaR.0&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:21] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfVJ&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:21] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfqJ&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:21] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfqL&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:22] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfvI&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:22] "GET /socket.io/?EIO=4&transport=polling&t=OOgcfqa&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:23] "GET /socket.io/?EIO=4&transport=polling&t=OOgcg1b&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:23] "GET /socket.io/?EIO=4&transport=polling&t=OOgcg1c&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:23] "GET /socket.io/?EIO=4&transport=polling&t=OOgcgHZ&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:23] "GET /socket.io/?EIO=4&transport=polling&t=OOgcgHZ&sid=xnAu2a2j3_qrMFa_AAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:24] "GET /socket.io/?EIO=4&transport=polling&t=OOgcgHn&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 06:40:24] "POST /socket.io/?EIO=4&transport=polling&t=OOgcgaI&sid=xYpJ-h69n79yJESWAAAE HTTP/1.1" 200 -
